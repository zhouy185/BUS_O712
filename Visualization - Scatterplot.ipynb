# %% [markdown]
# # Scatterplots and Bubble Charts

# %% [markdown]
# The `scatter()` function in the pyplot library helps us create scatterplots and bubble charts with different plotting options and formats. Options that we discussed in the line graph section apply to scatterplots as well. (e.g., adding legends, arguments, fmt option, legends, subplots, etc.). You can learn more about the arguments used in the `scatter()` function at this link [matplotlib.pyplot.scatter — documentation](matplotlib.pyplot.scatter).

# %% [markdown]
# ## Scatterplots in matplotlib

# %% [markdown]
# The `scatter()` function creates scatterplots. Like a line graph, a scatterplot requires two variables, one to be placed on the x-axis and the other one on the y-axis. The basic codes are shown as follows.
#
# `import matplotlib.pyplot as plt`
#
# `plt.scatter(xAxis, yAxis)`
#
# `plt.show()`

# %% [markdown]
# Let us build a scatterplot based on the following DataFrame loaded from a csv file. Let us download the "state.csv" file and place it to the "Data" folder; make sure that "Data" is in the same directory as your running notebook.

# %%
crime_df = pd.read_csv('Data/crime_data.csv')
crime_df.head()
# Out:
#    Unnamed: 0       State  Population  Murder.Rate  Grad.Rate Abbreviation  \
# 0           0     Alabama     4779736          5.7         72           AL
# 1           1      Alaska      710231          5.6         68           AK
# 2           2     Arizona     6392017          4.7         78           AZ
# 3           3    Arkansas     2915918          5.6         81           AR
# 4           4  California    37253956          4.4         76           CA
#
#    Region
# 0       4
# 1       3
# 2       3
# 3       4
# 4       3

# %% [markdown]
# The data represents the population as well as murder rate (per 100,000 residents) and high school graduation rate (percentage) for each of 50 US states. Note that in the column "Region", each number in the set $\{1,2,3,4\}$ represents one of the following regions:
#
# * 1: Northeast
# * 2: Midwest
# * 3: West
# * 4: South
#
# **Question**: Is murder rate correlated with the high school graduation rate?
#
# To answer the question, let us create a scatterplot between 'Grad.Rate' (on the horizontal axis) and 'Murder.rate' (vertical axis).

# %%
import matplotlib.pyplot as plt

plt.scatter(crime_df['Grad.Rate'],crime_df['Murder.Rate'],c=crime_df['Region'])
plt.title('Murder rate vs. high school graduation rate')
plt.xlabel('High school graduation rate')
plt.ylabel('Murder rate')
plt.show()

# %%
import seaborn as sns

sns.scatterplot(data=crime_df,x='Grad.Rate',y='Murder.Rate',hue='Region',size='Population',
                palette='bright',style='Region')
plt.title('Murder rate vs. high school graduation rate')
plt.xlabel('High school graduation rate')
plt.ylabel('Murder rate')
plt.show()

# %%
NE_states = [state.strip() 
             for state in "Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, Vermont,New Jersey, New York, Pennsylvania".split(",")]


MW_states = [state.strip()
             for state in "Illinois, Indiana, Michigan, Ohio, Wisconsin,Iowa, Kansas, Minnesota, Missouri, Nebraska, North Dakota, South Dakota".split(",")]

S_states = [state.strip()
    for state in "Delaware, Florida, Georgia, Maryland, North Carolina, South Carolina, Virginia, \
            Washington, D.C., West Virginia, Alabama, Kentucky, Mississippi, Tennessee, Arkansas, Louisiana, Oklahoma, Texas".split(",")]

W_states = [state.strip()
           for state in "Arizona, Colorado, Idaho, Montana, Nevada, New Mexico, Utah, Wyoming, Alaska, California, Hawaii, Oregon, Washington".split(",")]

all_states = NE_states+MW_states+S_states+W_states
state_reg = ['Northeast']*len(NE_states)+['Midwest']*len(MW_states)+['South']*len(S_states)+['West']*len(W_states)

dict_state_reg = dict(zip(all_states,state_reg))

# %%
dict_state_reg
# Out:
# {'Connecticut': 'Northeast',
#  'Maine': 'Northeast',
#  'Massachusetts': 'Northeast',
#  'New Hampshire': 'Northeast',
#  'Rhode Island': 'Northeast',
#  'Vermont': 'Northeast',
#  'New Jersey': 'Northeast',
#  'New York': 'Northeast',
#  'Pennsylvania': 'Northeast',
#  'Illinois': 'Midwest',
#  'Indiana': 'Midwest',
#  'Michigan': 'Midwest',
#  'Ohio': 'Midwest',
#  'Wisconsin': 'Midwest',
#  'Iowa': 'Midwest',
#  'Kansas': 'Midwest',
#  'Minnesota': 'Midwest',
#  'Missouri': 'Midwest',
#  'Nebraska': 'Midwest',
#  'North Dakota': 'Midwest',
#  'South Dakota': 'Midwest',
#  'Delaware': 'South',
#  'Florida': 'South',
#  'Georgia': 'South',
#  'Maryland': 'South',
#  'North Carolina': 'South',
#  'South Carolina': 'South',
#  'Virginia': 'South',
#  'Washington': 'West',
#  'D.C.': 'South',
#  'West Virginia': 'South',
#  'Alabama': 'South',
#  'Kentucky': 'South',
#  'Mississippi': 'South',
#  'Tennessee': 'South',
#  'Arkansas': 'South',
#  'Louisiana': 'South',
# ...

# %%
crime_df['Region']=[dict_state_reg[st] for st in crime_df['State']]

# %%
rg_map={'Northeast':1,'Midwest':2,'West':3,'South':4}
crime_df_1 = crime_df.drop('Region',axis=1)
crime_df_1['Region'] = [rg_map[state_r] for state_r in crime_df['Region']]
#[rg_map[state_r] for state_r in crime_df['Region']]

# %%
crime_df_1.to_csv('crime_data.csv')

# %%
crime_df.to_csv('Crime data.csv',index=False)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import numpy as np

tips = sns.load_dataset("tips")

group_sz = np.sort(tips["size"].unique())
group_sz*30
# Out:
# array([ 30,  60,  90, 120, 150, 180])

# %%
ax = sns.scatterplot(data=tips,x="total_bill",y="tip",marker="o",hue="time",size="size",
                sizes=(10,200),alpha=0.5,legend="full",style="time")
plt.show()

# %%
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
